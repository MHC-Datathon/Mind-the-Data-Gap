# %%
#importing packages for data visualization and analysis
import pandas as pd
import matplotlib.pyplot as plt

#two main variables we will be working with; associated directly with our data sources

exempt_df = pd.read_csv("dataset1.csv")
issued_df = pd.read_csv("dataset2.csv")

#gives a preview into each of the datasets
print("Exempt dataset shape:", exempt_df.shape)
display(exempt_df.head())

print("Issued dataset shape:", issued_df.shape)
display(issued_df.head())
# Out:
# Exempt dataset shape: (90819, 15)
#    Violation ID                                         Vehicle ID  \
# 0     489741940  7feac037b62d591ffb1214e356157f3dd197fc22fee5bb...
# 1     489741935  e9122b4e6dac9160ed4fca952a3815fe4c737bfc70cb97...
# 2     489741747  de04d0589e26e7da94c192dff0be14d105abcc8342c87f...
# 3     489741639  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 4     489741298  ebabc585284d95a10b6b45730c38fa55dfd57bcc5aea30...
#
#          First Occurrence         Last Occurrence            Violation Status  \
# 0  08/20/2025 10:52:57 AM  08/20/2025 11:16:57 AM  EXEMPT - EMERGENCY VEHICLE
# 1  08/20/2025 11:35:29 PM  08/20/2025 11:39:32 PM  EXEMPT - EMERGENCY VEHICLE
# 2  08/20/2025 11:18:06 PM  08/20/2025 11:24:10 PM  EXEMPT - EMERGENCY VEHICLE
# 3  08/20/2025 10:58:39 PM  08/20/2025 11:02:18 PM  EXEMPT - EMERGENCY VEHICLE
# 4  08/20/2025 07:51:36 PM  08/20/2025 09:22:42 PM  EXEMPT - EMERGENCY VEHICLE
#
#          Violation Type Bus Route ID  Violation Latitude  Violation Longitude  \
# 0       MOBILE BUS STOP         M101           40.815113           -73.955040
# 1       MOBILE BUS STOP         M101           40.795630           -73.941683
# 2       MOBILE BUS LANE         M101           40.808403           -73.946993
# 3  MOBILE DOUBLE PARKED         M101           40.842800           -73.934798
# 4  MOBILE DOUBLE PARKED         M101           40.842453           -73.935029
#
#    Stop ID                    Stop Name  Bus Stop Latitude  \
# 0   401458        AMSTERDAM AV/W 131 ST          40.816009
# 1   402704                3 AV/E 109 ST          40.793765
# 2   402658  W 125 ST/ADAM C POWELL BLVD          40.808700
# 3   405069        AMSTERDAM AV/W 175 ST          40.843810
# 4   402740        AMSTERDAM AV/W 171 ST          40.841978
#
#    Bus Stop Longitude        Violation Georeference  \
# 0          -73.954424   POINT (-73.95504 40.815113)
# 1          -73.943005   POINT (-73.941683 40.79563)
# 2          -73.947836  POINT (-73.946993 40.808403)
# 3          -73.934076    POINT (-73.934798 40.8428)
# 4          -73.935267  POINT (-73.935029 40.842453)
#
#           Bus Stop Georeference
# 0  POINT (-73.954424 40.816009)
# 1  POINT (-73.943005 40.793765)
# 2    POINT (-73.947836 40.8087)
# 3   POINT (-73.934076 40.84381)
# 4  POINT (-73.935267 40.841978)
# Issued dataset shape: (173103, 15)
#    Violation ID                                         Vehicle ID  \
# 0     488516121  642528f0cd869a4e8b83900ebed5bf1fa0c0ffd2395e44...
# 1     488516114  7510d1cf1c0eddb665f506ba933c3dc5c2a22e71479800...
# 2     488477643  c83fa1cbb96db6ed7ca17e96297213fac1601fa4a72b98...
# 3     488473567  ad306c4aff8cfdb162dcd22fb8ea0b91380ad55cf13cb7...
# 4     488472815  04f5ffea1b5b85bcb6daf3d19ed4998bc5ca7d93853fef...
#
#          First Occurrence         Last Occurrence  Violation Status  \
# 0  08/13/2025 12:29:07 AM  08/13/2025 12:34:08 AM  VIOLATION ISSUED
# 1  08/13/2025 08:42:47 AM  08/13/2025 08:51:13 AM  VIOLATION ISSUED
# 2  08/13/2025 09:20:43 AM  08/13/2025 09:30:03 AM  VIOLATION ISSUED
# 3  08/13/2025 08:20:36 AM  08/13/2025 08:47:14 AM  VIOLATION ISSUED
# 4  08/13/2025 08:34:54 AM  08/13/2025 08:45:09 AM  VIOLATION ISSUED
#
#     Violation Type Bus Route ID  Violation Latitude  Violation Longitude  \
# 0  MOBILE BUS LANE         M101           40.752435           -73.975316
# 1  MOBILE BUS LANE         M101           40.766024           -73.963286
# 2  MOBILE BUS LANE         M101           40.769135           -73.961101
# 3  MOBILE BUS LANE         M101           40.760673           -73.969209
# 4  MOBILE BUS LANE         M101           40.773190           -73.960127
#
#    Stop ID              Stop Name  Bus Stop Latitude  Bus Stop Longitude  \
# 0   402843   LEXINGTON AV/E 45 ST          40.753095          -73.974905
# 1   403545           3 AV/E 60 ST          40.762558          -73.965738
# 2   402688           3 AV/E 67 ST          40.767113          -73.962513
# 3   402670           3 AV/E 17 ST          40.735511          -73.985465
# 4   402811  LEXINGTON AV/E 110 ST          40.794544          -73.944667
#
#          Violation Georeference         Bus Stop Georeference
# 0  POINT (-73.975316 40.752435)  POINT (-73.974905 40.753095)
# 1  POINT (-73.963286 40.766024)  POINT (-73.965738 40.762558)
# 2  POINT (-73.961101 40.769135)  POINT (-73.962513 40.767113)
# 3  POINT (-73.969209 40.760673)  POINT (-73.985465 40.735511)
# 4   POINT (-73.960127 40.77319)  POINT (-73.944667 40.794544)

# %%
#Reveals the top 10 Vehicles with the highest violation counts
exempt_repeat = (
    exempt_df.groupby('Vehicle ID')
    .size()
    .reset_index(name='violation_count')
    .sort_values(by='violation_count', ascending=False)
    .head(10)
)

print(exempt_repeat)
# Out:
#                                               Vehicle ID  violation_count
# 2835   1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...             1340
# 9586   6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...              903
# 9258   6979a2434b4611cf1ebf80624eaeb29622929b061958b9...              903
# 3756   2a8ac01b157a97b3c124cf33322e71c31062b815dd3b0a...              864
# 20579  ebabc585284d95a10b6b45730c38fa55dfd57bcc5aea30...              787
# 17872  cbebd9b5a63416b9c246a35d3b5fc36214871dab0e5ccf...              729
# 11305  80e7bae594e62aaaf4ed702b8230dfd12559743828922b...              628
# 3232   24908a1da372fdb0f5f03bcf7001ee589cf492894d5792...              605
# 8429   6059dcc4ef4516ca9f357ca2a789b9c4ca9c633258f212...              537
# 1278   0e92016a483877f5c62115578a642425d710c43560e00c...              537

# %%
#Prints the top 10 hotspot locations 
print("Top 10 Exempt Violation Hotspots")
display(location_counts.head(10))

plt.figure(figsize=(10,8))
plt.scatter(location_counts['lon_bin'], location_counts['lat_bin'], 
            s=location_counts['violation_count']*10,
            c=location_counts['violation_count'], cmap='Reds', alpha=0.6)
plt.colorbar(label='Number of Violations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Exempt Violation Hotspots - M101')
plt.show()
# Out:
# Top 10 Exempt Violation Hotspots
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #Prints the top 10 hotspot locations
#       2 print("Top 10 Exempt Violation Hotspots")
# ----> 3 display(location_counts.head(10))
#       5 plt.figure(figsize=(10,8))
#       6 plt.scatter(location_counts['lon_bin'], location_counts['lat_bin'],
#       7             s=location_counts['violation_count']*10,
#       8             c=location_counts['violation_count'], cmap='Reds', alpha=0.6)
#
# NameError: name 'location_counts' is not defined

# %%
#Focuses in on the top exempt violator, its locations, what stops, what type of violations etc
top_offender = exempt_repeat.iloc[0]
vehicle_id = top_offender['Vehicle ID']

print("Top Exempt Offender Vehicle ID:", vehicle_id)
print("Total Violations:", top_offender['violation_count'])

vehicle_df = exempt_df[exempt_df['Vehicle ID'] == vehicle_id]

print("\nSample Records for This Vehicle")
display(vehicle_df.head(10))

print("\nViolation Types Breakdown")
display(vehicle_df['Violation Type'].value_counts())

print("\nTop 5 Stop Names for This Vehicle")
display(vehicle_df['Stop Name'].value_counts().head(5))
# Out:
# Top Exempt Offender Vehicle ID: 1feaad876c46cfe1cc4ee357e410ec2054c5c231d268169dfdd9527c1c084a80
# Total Violations: 1340
#
# Sample Records for This Vehicle
#      Violation ID                                         Vehicle ID  \
# 34      489736398  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
# 58      489734756  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
# 113     489651592  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
# 237     489517428  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
# 265     489510799  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
# 350     489366263  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
# 353     489366201  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
# 359     489366175  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
# 427     489355089  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
# 443     489348119  1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...
#
#            First Occurrence         Last Occurrence  \
# 34   08/20/2025 04:38:40 PM  08/20/2025 05:28:26 PM
# 58   08/20/2025 12:24:56 PM  08/20/2025 02:08:55 PM
# 113  08/20/2025 05:54:18 AM  08/20/2025 07:54:30 AM
# 237  08/19/2025 08:50:37 PM  08/19/2025 10:26:28 PM
# 265  08/19/2025 04:28:20 PM  08/19/2025 05:13:17 PM
# 350  08/19/2025 12:10:13 PM  08/19/2025 01:02:32 PM
# 353  08/19/2025 09:28:59 AM  08/19/2025 09:41:13 AM
# 359  08/19/2025 05:53:21 AM  08/19/2025 06:25:57 AM
# 427  08/18/2025 09:04:05 PM  08/18/2025 09:49:19 PM
# 443  08/18/2025 05:20:50 PM  08/18/2025 05:31:14 PM
#
#                Violation Status   Violation Type Bus Route ID  \
# 34   EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
# 58   EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
# 113  EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
# 237  EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
# 265  EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
# 350  EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
# 353  EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
# 359  EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
# 427  EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
# 443  EXEMPT - EMERGENCY VEHICLE  MOBILE BUS STOP         M101
#
#      Violation Latitude  Violation Longitude  Stop ID              Stop Name  \
# 34            40.766589           -73.962891   403545           3 AV/E 60 ST
# 58            40.766608           -73.962886   405070  AMSTERDAM AV/W 165 ST
# 113           40.766574           -73.962906   402687           3 AV/E 65 ST
# 237           40.766551           -73.962856   403545           3 AV/E 60 ST
# 265           40.766557           -73.962860   403545           3 AV/E 60 ST
# 350           40.766575           -73.962886   403545           3 AV/E 60 ST
# 353           40.766559           -73.962825   403545           3 AV/E 60 ST
# 359           40.766558           -73.962860   402687           3 AV/E 65 ST
# 427           40.766570           -73.962865   402687           3 AV/E 65 ST
# 443           40.766567           -73.962884   402687           3 AV/E 65 ST
#
#      Bus Stop Latitude  Bus Stop Longitude        Violation Georeference  \
# 34           40.762558          -73.965738  POINT (-73.962891 40.766589)
# 58           40.837603          -73.938646  POINT (-73.962886 40.766608)
# 113          40.765599          -73.963509  POINT (-73.962906 40.766574)
# 237          40.762558          -73.965738  POINT (-73.962856 40.766551)
# 265          40.762558          -73.965738   POINT (-73.96286 40.766557)
# 350          40.762558          -73.965738  POINT (-73.962886 40.766575)
# 353          40.762558          -73.965738  POINT (-73.962825 40.766559)
# 359          40.765599          -73.963509   POINT (-73.96286 40.766558)
# 427          40.765599          -73.963509   POINT (-73.962865 40.76657)
# 443          40.765599          -73.963509  POINT (-73.962884 40.766567)
#
#             Bus Stop Georeference  lat_bin  lon_bin
# 34   POINT (-73.965738 40.762558)   40.767  -73.963
# 58   POINT (-73.938646 40.837603)   40.767  -73.963
# 113  POINT (-73.963509 40.765599)   40.767  -73.963
# 237  POINT (-73.965738 40.762558)   40.767  -73.963
# 265  POINT (-73.965738 40.762558)   40.767  -73.963
# 350  POINT (-73.965738 40.762558)   40.767  -73.963
# 353  POINT (-73.965738 40.762558)   40.767  -73.963
# 359  POINT (-73.963509 40.765599)   40.767  -73.963
# 427  POINT (-73.963509 40.765599)   40.767  -73.963
# 443  POINT (-73.963509 40.765599)   40.767  -73.963
# Violation Types Breakdown
# Violation Type
# MOBILE BUS STOP    1338
# MOBILE BUS LANE       2
# Name: count, dtype: int64
# Top 5 Stop Names for This Vehicle
# Stop Name
# 3 AV/E 60 ST             535
# 3 AV/E 65 ST             438
# 3 AV/E 37 ST              91
# E 125 ST/PARK AV          36
# AMSTERDAM AV/W 165 ST     32
# Name: count, dtype: int64

# %%
#Focuses in on the 2nd top exempt violator, its locations, what stops, what type of violations etc
top_offender = exempt_repeat.iloc[1]
vehicle_id = top_offender['Vehicle ID']

print("Top Exempt Offender Vehicle ID:", vehicle_id)
print("Total Violations:", top_offender['violation_count'])

vehicle_df = exempt_df[exempt_df['Vehicle ID'] == vehicle_id]

print("\nSample Records for This Vehicle")
display(vehicle_df.head(10))

print("\nViolation Types Breakdown")
display(vehicle_df['Violation Type'].value_counts())

print("\nTop 5 Stop Names for This Vehicle")
display(vehicle_df['Stop Name'].value_counts().head(5))
# Out:
# Top Exempt Offender Vehicle ID: 6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31acec87ab5642558d4360b
# Total Violations: 903
#
# Sample Records for This Vehicle
#      Violation ID                                         Vehicle ID  \
# 3       489741639  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 27      489736674  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 96      489655728  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 129     489646517  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 145     489642181  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 150     489580198  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 151     489580003  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 154     489579916  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 157     489579895  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
# 173     489579356  6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...
#
#            First Occurrence         Last Occurrence  \
# 3    08/20/2025 10:58:39 PM  08/20/2025 11:02:18 PM
# 27   08/20/2025 05:30:41 PM  08/20/2025 05:36:34 PM
# 96   08/20/2025 09:28:42 AM  08/20/2025 09:37:47 AM
# 129  08/20/2025 05:36:52 AM  08/20/2025 05:56:23 AM
# 145  08/20/2025 12:03:44 AM  08/20/2025 12:20:20 AM
# 150  08/19/2025 11:11:19 PM  08/19/2025 11:39:52 PM
# 151  08/19/2025 07:00:30 PM  08/19/2025 07:08:29 PM
# 154  08/19/2025 04:59:11 PM  08/19/2025 06:06:27 PM
# 157  08/19/2025 08:09:17 PM  08/19/2025 09:09:21 PM
# 173  08/19/2025 02:57:46 PM  08/19/2025 03:12:47 PM
#
#                Violation Status        Violation Type Bus Route ID  \
# 3    EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 27   EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 96   EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 129  EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 145  EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 150  EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 151  EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 154  EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 157  EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 173  EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
#
#      Violation Latitude  Violation Longitude  Stop ID              Stop Name  \
# 3             40.842800           -73.934798   405069  AMSTERDAM AV/W 175 ST
# 27            40.842786           -73.934831   405069  AMSTERDAM AV/W 175 ST
# 96            40.842813           -73.934786   405069  AMSTERDAM AV/W 175 ST
# 129           40.842794           -73.934803   405069  AMSTERDAM AV/W 175 ST
# 145           40.842776           -73.934817   405069  AMSTERDAM AV/W 175 ST
# 150           40.842809           -73.934786   405069  AMSTERDAM AV/W 175 ST
# 151           40.842799           -73.934821   405069  AMSTERDAM AV/W 175 ST
# 154           40.842791           -73.934823   405069  AMSTERDAM AV/W 175 ST
# 157           40.842781           -73.934810   405069  AMSTERDAM AV/W 175 ST
# 173           40.842806           -73.934813   405069  AMSTERDAM AV/W 175 ST
#
#      Bus Stop Latitude  Bus Stop Longitude        Violation Georeference  \
# 3             40.84381          -73.934076    POINT (-73.934798 40.8428)
# 27            40.84381          -73.934076  POINT (-73.934831 40.842786)
# 96            40.84381          -73.934076  POINT (-73.934786 40.842813)
# 129           40.84381          -73.934076  POINT (-73.934803 40.842794)
# 145           40.84381          -73.934076  POINT (-73.934817 40.842776)
# 150           40.84381          -73.934076  POINT (-73.934786 40.842809)
# 151           40.84381          -73.934076  POINT (-73.934821 40.842799)
# 154           40.84381          -73.934076  POINT (-73.934823 40.842791)
# 157           40.84381          -73.934076   POINT (-73.93481 40.842781)
# 173           40.84381          -73.934076  POINT (-73.934813 40.842806)
#
#            Bus Stop Georeference
# 3    POINT (-73.934076 40.84381)
# 27   POINT (-73.934076 40.84381)
# 96   POINT (-73.934076 40.84381)
# 129  POINT (-73.934076 40.84381)
# 145  POINT (-73.934076 40.84381)
# 150  POINT (-73.934076 40.84381)
# 151  POINT (-73.934076 40.84381)
# 154  POINT (-73.934076 40.84381)
# 157  POINT (-73.934076 40.84381)
# 173  POINT (-73.934076 40.84381)
# Violation Types Breakdown
# Violation Type
# MOBILE DOUBLE PARKED    890
# MOBILE BUS STOP          10
# MOBILE BUS LANE           3
# Name: count, dtype: int64
# Top 5 Stop Names for This Vehicle
# Stop Name
# AMSTERDAM AV/W 175 ST          524
# AMSTERDAM AV/W 171 ST          336
# AMSTERDAM AV/W 161 ST            4
# AMSTERDAM AV/W 158 ST            3
# W 125 ST/ADAM C POWELL BLVD      3
# Name: count, dtype: int64

# %%
#Focuses in on the 3rd top exempt violator, its locations, what stops, what type of violations etc
top_offender = exempt_repeat.iloc[2]
vehicle_id = top_offender['Vehicle ID']

print("Top Exempt Offender Vehicle ID:", vehicle_id)
print("Total Violations:", top_offender['violation_count'])

vehicle_df = exempt_df[exempt_df['Vehicle ID'] == vehicle_id]

print("\nSample Records for This Vehicle")
display(vehicle_df.head(10))

print("\nViolation Types Breakdown")
display(vehicle_df['Violation Type'].value_counts())

print("\nTop 5 Stop Names for This Vehicle")
display(vehicle_df['Stop Name'].value_counts().head(5))
# Out:
# Top Exempt Offender Vehicle ID: 6979a2434b4611cf1ebf80624eaeb29622929b061958b956f0d93024261a4a3c
# Total Violations: 903
#
# Sample Records for This Vehicle
#        Violation ID                                         Vehicle ID  \
# 4988      486068585  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
# 5316      485896686  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
# 17231     478462999  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
# 17233     478462926  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
# 17960     478051747  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
# 20118     476539879  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
# 35910     467699039  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
# 35927     467698464  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
# 35936     467696804  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
# 46463     462761740  6979a2434b4611cf1ebf80624eaeb29622929b061958b9...
#
#              First Occurrence         Last Occurrence  \
# 4988   07/30/2025 12:44:20 PM  07/30/2025 12:49:42 PM
# 5316   07/29/2025 02:46:14 PM  07/29/2025 02:55:00 PM
# 17231  06/14/2025 02:58:18 PM  06/14/2025 03:38:58 PM
# 17233  06/14/2025 02:58:18 PM  06/14/2025 03:04:22 PM
# 17960  06/13/2025 12:43:40 PM  06/13/2025 12:50:19 PM
# 20118  06/04/2025 04:44:12 PM  06/04/2025 04:46:43 PM
# 35910  04/18/2025 12:29:14 PM  04/18/2025 12:41:54 PM
# 35927  04/18/2025 10:11:59 AM  04/18/2025 10:24:29 AM
# 35936  04/18/2025 07:54:54 AM  04/18/2025 08:07:00 AM
# 46463  03/18/2025 11:20:08 AM  03/18/2025 11:41:24 AM
#
#                  Violation Status        Violation Type Bus Route ID  \
# 4988   EXEMPT - EMERGENCY VEHICLE       MOBILE BUS LANE         M101
# 5316   EXEMPT - EMERGENCY VEHICLE       MOBILE BUS LANE         M101
# 17231  EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 17233  EXEMPT - EMERGENCY VEHICLE  MOBILE DOUBLE PARKED         M101
# 17960  EXEMPT - EMERGENCY VEHICLE       MOBILE BUS LANE         M101
# 20118  EXEMPT - EMERGENCY VEHICLE       MOBILE BUS STOP         M101
# 35910  EXEMPT - EMERGENCY VEHICLE       MOBILE BUS STOP         M101
# 35927  EXEMPT - EMERGENCY VEHICLE       MOBILE BUS STOP         M101
# 35936  EXEMPT - EMERGENCY VEHICLE       MOBILE BUS STOP         M101
# 46463  EXEMPT - EMERGENCY VEHICLE       MOBILE BUS STOP         M101
#
#        Violation Latitude  Violation Longitude  Stop ID  \
# 4988            40.811021           -73.953195   402723
# 5316            40.806688           -73.942850   402506
# 17231           40.814438           -73.955520   401458
# 17233           40.814439           -73.955521   401459
# 17960           40.811073           -73.953294   402723
# 20118           40.811589           -73.954575   402653
# 35910           40.814853           -73.955287   401459
# 35927           40.814879           -73.955228   401459
# 35936           40.814875           -73.955239   401459
# 46463           40.814917           -73.955171   401458
#
#                      Stop Name  Bus Stop Latitude  Bus Stop Longitude  \
# 4988   W 125 ST/MORNINGSIDE AV          40.811402          -73.954184
# 5316             W 125 ST/5 AV          40.806542          -73.942440
# 17231    AMSTERDAM AV/W 131 ST          40.816009          -73.954424
# 17233    AMSTERDAM AV/W 129 ST          40.814859          -73.955250
# 17960  W 125 ST/MORNINGSIDE AV          40.811402          -73.954184
# 20118    W 125 ST/AMSTERDAM AV          40.812602          -73.955693
# 35910    AMSTERDAM AV/W 129 ST          40.814859          -73.955250
# 35927    AMSTERDAM AV/W 129 ST          40.814859          -73.955250
# 35936    AMSTERDAM AV/W 129 ST          40.814859          -73.955250
# 46463    AMSTERDAM AV/W 131 ST          40.816009          -73.954424
#
#              Violation Georeference         Bus Stop Georeference  lat_bin  \
# 4988   POINT (-73.953195 40.811021)  POINT (-73.954184 40.811402)   40.811
# 5316    POINT (-73.94285 40.806688)   POINT (-73.94244 40.806542)   40.807
# 17231   POINT (-73.95552 40.814438)  POINT (-73.954424 40.816009)   40.814
# 17233  POINT (-73.955521 40.814439)   POINT (-73.95525 40.814859)   40.814
# 17960  POINT (-73.953294 40.811073)  POINT (-73.954184 40.811402)   40.811
# 20118  POINT (-73.954575 40.811589)  POINT (-73.955693 40.812602)   40.812
# 35910  POINT (-73.955287 40.814853)   POINT (-73.95525 40.814859)   40.815
# 35927  POINT (-73.955228 40.814879)   POINT (-73.95525 40.814859)   40.815
# 35936  POINT (-73.955239 40.814875)   POINT (-73.95525 40.814859)   40.815
# 46463  POINT (-73.955171 40.814917)  POINT (-73.954424 40.816009)   40.815
#
#        lon_bin
# 4988   -73.953
# 5316   -73.943
# 17231  -73.956
# 17233  -73.956
# 17960  -73.953
# 20118  -73.955
# 35910  -73.955
# 35927  -73.955
# 35936  -73.955
# 46463  -73.955
# Violation Types Breakdown
# Violation Type
# MOBILE BUS STOP         898
# MOBILE BUS LANE           3
# MOBILE DOUBLE PARKED      2
# Name: count, dtype: int64
# Top 5 Stop Names for This Vehicle
# Stop Name
# AMSTERDAM AV/W 131 ST      626
# AMSTERDAM AV/W 129 ST      267
# W 125 ST/AMSTERDAM AV        3
# W 125 ST/MORNINGSIDE AV      2
# W 125 ST/5 AV                1
# Name: count, dtype: int64

# %%
violation_status_counts = exempt_df['Violation Status'].value_counts()
print("Violation Status Counts:")
print(violation_status_counts)
print("\n")

violation_type_count = exempt_df['Violation Type'].value_counts()
print("Violation Type Counts:")
print(violation_type_count)
print("\n")

stop_name_counts = exempt_df['Stop Name'].value_counts()
print("Stop Name Counts:")
print(stop_name_counts)


# Individual bar graphs
def plot_counts(column_name, title, top_n=None):
    counts = exempt_df[column_name].value_counts()
    if top_n:
        counts = counts.head(top_n) 

    plt.figure(figsize=(10,6))
    plt.bar(counts.index, counts.values, color='skyblue') 
    plt.title(title)
    plt.xticks(rotation=45, ha='right')
    plt.ylabel('Count')
    plt.xlabel(column_name)
    plt.tight_layout()
    plt.show()

# Plot Violation Status
plot_counts('Violation Status', 'Violation Status Counts')

# Plot Violation Type
plot_counts('Violation Type', 'Violation Type Counts')

# Plot Stop Name (top 20 to keep it readable)
plot_counts('Stop Name', 'Top 20 Stop Name Counts', top_n=20)
# Out:
# Violation Status Counts:
# Violation Status
# EXEMPT - EMERGENCY VEHICLE      38431
# EXEMPT - COMMERCIAL UNDER 20    30021
# EXEMPT - OTHER                  12679
# EXEMPT - BUS/PARATRANSIT         9688
# Name: count, dtype: int64
#
#
# Violation Type Counts:
# Violation Type
# MOBILE DOUBLE PARKED    48486
# MOBILE BUS STOP         31637
# MOBILE BUS LANE         10696
# Name: count, dtype: int64
#
#
# Stop Name Counts:
# Stop Name
# AMSTERDAM AV/W 175 ST          6745
# AMSTERDAM AV/W 171 ST          5058
# 3 AV/E 14 ST                   3090
# AMSTERDAM AV/W 161 ST          2771
# LEXINGTON AV/E 79 ST           2294
#                                ...
# SAINT NICHOLAS AV/W 167 ST        1
# E 42 ST/LEXINGTON AV              1
# W 178 ST/FORT WASHINGTON AV       1
# E 86 ST/MADISON AV                1
# E 14 ST/UNIVERSITY PL             1
# Name: count, Length: 253, dtype: int64

# %%
# Exempt repeat offenders
exempt_repeat = (
    exempt_df.groupby('Vehicle ID')
    .size()
    .reset_index(name='count')
    .sort_values(by='count', ascending=False)
)
print(exempt_repeat)

# Non-exempt repeat offenders
non_exempt_repeat = (
    issued_df.groupby('Vehicle ID')
    .size()
    .reset_index(name='count')
    .sort_values(by='count', ascending=False)
)

print(non_exempt_repeat)

top_exempt = exempt_repeat.head(10)
top_exempt = top_exempt.reset_index(drop=True)  # reset index to 0-9
top_exempt['Rank'] = top_exempt.index + 1      # create Rank column 1-10

plt.figure(figsize=(12,6))
plt.bar(top_exempt['Rank'], top_exempt['count'], color='hotpink', alpha=0.7)
plt.xlabel('Top 10 Exempt Offenders (Rank)')
plt.ylabel('Number of Exempt Violations')
plt.title('Top 10 Exempt Repeat Offenders')
plt.xticks(top_exempt['Rank'])
plt.show()

# Top 10 non-exempt repeat offenders
top_non_exempt = non_exempt_repeat.head(10)
top_non_exempt = top_non_exempt.reset_index(drop=True)
top_non_exempt['Rank'] = top_non_exempt.index + 1

plt.figure(figsize=(12,6))
plt.bar(top_non_exempt['Rank'], top_non_exempt['count'], color='purple', alpha=0.7)
plt.xlabel('Top 10 Non-Exempt Offenders (Rank)')
plt.ylabel('Number of Non-Exempt Violations')
plt.title('Top 10 Non-Exempt Repeat Offenders')
plt.xticks(top_non_exempt['Rank'])
plt.show()
# Out:
#                                               Vehicle ID  count
# 2835   1feaad876c46cfe1cc4ee357e410ec2054c5c231d26816...   1340
# 9586   6d7caef8bf15e2bf8d46aa1e6dd8c0da1ae2fbc5b31ace...    903
# 9258   6979a2434b4611cf1ebf80624eaeb29622929b061958b9...    903
# 3756   2a8ac01b157a97b3c124cf33322e71c31062b815dd3b0a...    864
# 20579  ebabc585284d95a10b6b45730c38fa55dfd57bcc5aea30...    787
# ...                                                  ...    ...
# 9736   6f2f4de4ab6f5d8f409ae0c62205f2649fd4443c82985b...      1
# 9738   6f2fb7c6f703653aacb70171ab86f1819bc500574605e4...      1
# 9739   6f37c88c7017db34987d1f9d2d9da51cf87ea8ef73e5a7...      1
# 9741   6f3dbb6ee50899f9d4620dcab3b09bc14b6d3de10d0e09...      1
# 11185  7fc47331bec445905cb4c490b583fdb52a843ecebea822...      1
#
# [22371 rows x 2 columns]
#                                               Vehicle ID  count
# 15879  28d5db97c873ef7c0baf48e363edeeeb9575ef6e5d3aca...    186
# 16301  29d82bbcf10821ff01ab68a24c4f023b0b2d6b465a5324...    130
# 43896  70b7476630af8837ec4394a6b7ffe75faf6035fa1d17cb...    126
# 84183  d78df2e07e63545bae8f6a02d2ba73e06a9c0474d75579...    123
# 20092  33c7e0d26b8101bf32ea372a8baff70ac666ab51aeff65...    123
# ...                                                  ...    ...
# 38425  6310adf2ce4780ee51e593d76923bb142dcafa0570031f...      1
# 38424  630fc70ca22c0a993a938ccc91aac17bb204a2e9def98d...      1
# 38422  630e31870be7387ca343d02d5fa96041311767268dcf6e...      1
# 38421  630de39cf938cde97e0e121dd1398ea82c88210253fcad...      1
# 50019  80113c72df3f7e05d6604e9b2aa059336b781dee1fc9a7...      1
#
# [100039 rows x 2 columns]

# %%
approx_coords = {
    'Amsterdam Ave/ W 175 St': {'lat': 40.841, 'lon': -73.939},
    'Amsterdam Ave/ W 171 St': {'lat': 40.845, 'lon': -73.942}
}

for spot, coord in approx_coords.items():
    # Find violations within 0.002 degrees (~200m) of the spot
    nearby = exempt_df[
        (exempt_df['Violation Latitude'] >= coord['lat'] - 0.002) &
        (exempt_df['Violation Latitude'] <= coord['lat'] + 0.002) &
        (exempt_df['Violation Longitude'] >= coord['lon'] - 0.002) &
        (exempt_df['Violation Longitude'] <= coord['lon'] + 0.002)
    ][['Vehicle ID', 'Violation Latitude', 'Violation Longitude']]
    
    print(f"\nViolations near {spot}:")
    print(nearby.head(10))
# Out:
# Violations near Amsterdam Ave/ W 175 St:
#                                              Vehicle ID  Violation Latitude  \
# 643   fc9c49fd8843d689148238f3f69b051baa305b3a472741...           40.839610
# 1160  92f6a3e916473f0dc90cbcf2403be5be7b2b72ae18b2b1...           40.839526
# 1718  fc9c49fd8843d689148238f3f69b051baa305b3a472741...           40.839577
# 1777  932dd0947e491ed0c51ac4bb9e90f31695d8365425c63c...           40.839742
# 2313  fa631d4544736f7196749a8b06a72f5983c94f38fc926f...           40.839033
# 2319  fa631d4544736f7196749a8b06a72f5983c94f38fc926f...           40.839013
# 3022  6dc34b83b477c2c73ec2d9ffb526264ded101d965f3ef0...           40.839020
# 3023  6dc34b83b477c2c73ec2d9ffb526264ded101d965f3ef0...           40.839026
# 4300  f2d324e4cee8e3bef7cb04793ee7429eb786dfa755c4a2...           40.839565
# 4301  34ec5e76106f48198977db1024330f60a6dfbd4da80fb6...           40.839465
#
#       Violation Longitude
# 643            -73.937089
# 1160           -73.937227
# 1718           -73.937082
# 1777           -73.937058
# 2313           -73.937535
# 2319           -73.937552
# 3022           -73.937557
# 3023           -73.937557
# 4300           -73.937109
# 4301           -73.937183
#
# Violations near Amsterdam Ave/ W 171 St:
# Empty DataFrame
# Columns: [Vehicle ID, Violation Latitude, Violation Longitude]
# Index: []

# %%
# Make sure 'First Occurrence' is in datetime format
exempt_df['First Occurrence'] = pd.to_datetime(exempt_df['First Occurrence'])

# Extract the hour (0-23) and convert to time format
exempt_df['Hour'] = exempt_df['First Occurrence'].dt.hour
exempt_df['Hour Time'] = pd.to_datetime(exempt_df['Hour'], format='%H').dt.time

# Count violations per hour
violations_by_hour = exempt_df.groupby('Hour Time').size().reset_index(name='count')

# Sort by hour just in case
violations_by_hour = violations_by_hour.sort_values(by='Hour Time')

print(violations_by_hour)

# Plot
plt.figure(figsize=(12,6))
plt.bar(violations_by_hour['Hour Time'].astype(str), violations_by_hour['count'], color='green', alpha=0.7)
plt.xlabel('Hour of Day')
plt.ylabel('Number of Violations')
plt.title('Violations by Hour of Day')
plt.xticks(rotation=45)
plt.show()
# Out:
#    Hour Time  count
# 0   00:00:00   1501
# 1   01:00:00    996
# 2   02:00:00    474
# 3   03:00:00    499
# 4   04:00:00    722
# 5   05:00:00   1634
# 6   06:00:00   3597
# 7   07:00:00   4891
# 8   08:00:00   5712
# 9   09:00:00   6958
# 10  10:00:00   7654
# 11  11:00:00   7216
# 12  12:00:00   7449
# 13  13:00:00   7158
# 14  14:00:00   6024
# 15  15:00:00   5096
# 16  16:00:00   4624
# 17  17:00:00   3810
# 18  18:00:00   3446
# 19  19:00:00   3298
# 20  20:00:00   2681
# 21  21:00:00   2118
# 22  22:00:00   1685
# 23  23:00:00   1576

# %%
# Filter for June 2025 and Exempt violations
june_exempt = exempt_df[
    (exempt_df['Violation Status'] == 'EXEMPT - COMMERCIAL UNDER 20') &
    (exempt_df['First Occurrence'].dt.month == 6) &
    (exempt_df['First Occurrence'].dt.year == 2025)
]

june_counts = june_exempt.groupby(['Vehicle ID', 'Violation Status']).size().reset_index(name='Exempt Count')

repeat_offenders = june_counts[june_counts['Exempt Count'] > 1]

repeat_offenders_sorted = repeat_offenders.sort_values(by='Exempt Count', ascending=False)

print("Repeat exempt offenders in June 2025:")
print(repeat_offenders)

print("Top 10 repeat exempt offenders in June 2025:")
print(repeat_offenders_sorted.head(10))

# Show the single worst offender
print("\nWorst offender in June 2025:")
print(repeat_offenders_sorted.head(1))
# Out:
# Repeat exempt offenders in June 2025:
#                                              Vehicle ID  \
# 5     01cfccc6c0f64c5b8cd572cf240608b163f9c424c3d04f...
# 6     02008c14c534cb81837934c559ac864b191b2bee8e1a05...
# 9     021ef97c6b5b583b8d54ec9cc38ae47a2f3d9654143e10...
# 13    02673ffc741161c60058b523a8a22e920e2fceb4a9e56e...
# 15    0320d4702845b578b20a3cbb8f0e46ddde054773311442...
# ...                                                 ...
# 1667  fdec0b6b6b313ad0753f121d9b591f16914b45c20c02f4...
# 1671  fe5f070cdd57062282ac3da3e98e1c5ee760f42b77bf74...
# 1675  fe77e95c9b49ee3f4cf163528055b4d7cb6ccea44348f1...
# 1677  fee0c5d403d872b5b0e3fddac21ef98a65fa1a141bc6b8...
# 1682  ffe6a79b8ba3375f613747dbb0532bc4a4fae18e959e51...
#
#                   Violation Status  Exempt Count
# 5     EXEMPT - COMMERCIAL UNDER 20             2
# 6     EXEMPT - COMMERCIAL UNDER 20             3
# 9     EXEMPT - COMMERCIAL UNDER 20             4
# 13    EXEMPT - COMMERCIAL UNDER 20             3
# 15    EXEMPT - COMMERCIAL UNDER 20             2
# ...                            ...           ...
# 1667  EXEMPT - COMMERCIAL UNDER 20             4
# 1671  EXEMPT - COMMERCIAL UNDER 20             4
# 1675  EXEMPT - COMMERCIAL UNDER 20             3
# 1677  EXEMPT - COMMERCIAL UNDER 20             2
# 1682  EXEMPT - COMMERCIAL UNDER 20             2
#
# [404 rows x 3 columns]
# Top 10 repeat exempt offenders in June 2025:
#                                              Vehicle ID  \
# 1491  e3ef8ba6456589dfeb61c2cf7167006c12171dc9f5d9a5...
# 241   263d38c53e0f524f0cf1bb3e9529561641bb29960ea35b...
# 1590  f3e3c973e25689ed09c8468c44d0c6634a3ffded2bb1af...
# 76    0cd7f6bd48dc9e41d9194e1ce7cf6a9c29817039f1b8fc...
# 727   756d6d46e801199d71d8c8d6b74fdc8e34c1d48054e04e...
# 50    08f4d1dfbf742f061b7a8ea85ff52d74a5bcd85b78bb39...
# 361   37fb357e198016a7e1bca9ea407325ae1c7ba6958b4a59...
# 261   29d82bbcf10821ff01ab68a24c4f023b0b2d6b465a5324...
# 192   1e4b7a91a33090bf8b7f715b1e0cab45f3baa5a116ce51...
# 967   971267ef6d3ee741b57beae39852d802b71834abb3ec62...
#
#                   Violation Status  Exempt Count
# 1491  EXEMPT - COMMERCIAL UNDER 20            37
# 241   EXEMPT - COMMERCIAL UNDER 20            28
# 1590  EXEMPT - COMMERCIAL UNDER 20            24
# 76    EXEMPT - COMMERCIAL UNDER 20            19
# 727   EXEMPT - COMMERCIAL UNDER 20            18
# 50    EXEMPT - COMMERCIAL UNDER 20            18
# 361   EXEMPT - COMMERCIAL UNDER 20            17
# 261   EXEMPT - COMMERCIAL UNDER 20            17
# 192   EXEMPT - COMMERCIAL UNDER 20            17
# 967   EXEMPT - COMMERCIAL UNDER 20            16
#
# Worst offender in June 2025:
#                                              Vehicle ID  \
# 1491  e3ef8ba6456589dfeb61c2cf7167006c12171dc9f5d9a5...
#
#                   Violation Status  Exempt Count
# 1491  EXEMPT - COMMERCIAL UNDER 20            37
